# %%
# importando bibliotecas
import pandas as pd
import psycopg2 as pg
from sqlalchemy import create_engine

# %%
# criando conexão com o banco
engine = create_engine('postgresql://uizliondmcgttz:cb0d11ae81949fc4be4c40d5b3de2e2f623d94b16e12d21f83bdbb50db636373@ec2-54-164-40-66.compute-1.amazonaws.com:5432/deqf9j26o8pgv5')

# %%
#buscando os dados com pandas
query_forms = "SELECT * FROM forms"
df_forms = pd.read_sql (query_forms, con=engine)

# %%
#buscando dados com pandas
query_orders = "SELECT * FROM orders"
df_orders = pd.read_sql (query_orders, con=engine)

# %%
#inicio do tratamento de dados
df_forms.shape
# Out:
# (5000, 3)

# %%
df_forms.head()
# Out:
#                                      id hair_type  age
# 0  2d3f90ca-e262-4b32-8b57-80fb0170bf5a  ondulado   20
# 1  3cb90d19-02a1-43f3-a36f-b421e41b3d2f  ondulado   30
# 2  1cd08ffd-4e85-4f1d-bdc1-afb292b056db  cacheado   38
# 3  d518ff19-df6a-445f-a13c-8b45b2addd7b  cacheado   20
# 4  c2baa4bc-9fe3-4cfe-809f-c52a728fa5bb  ondulado   29

# %%
# verificando missing values
df_forms.isna().sum()
# Out:
# id           0
# hair_type    0
# age          0
# dtype: int64

# %%
df_orders.shape
# Out:
# (5000, 4)

# %%
df_orders.head()
# Out:
#    id                          created  value  \
# 0   0        2022-01-05 00:00:00+00:00  70.33
# 1   1 2022-01-05 00:27:32.980132+00:00  51.44
# 2   2 2022-01-05 00:55:05.960265+00:00  56.83
# 3   3 2022-01-05 01:22:38.940397+00:00  91.51
# 4   4 2022-01-05 01:50:11.920530+00:00  54.35
#
#                                 form_id
# 0  2d3f90ca-e262-4b32-8b57-80fb0170bf5a
# 1  3cb90d19-02a1-43f3-a36f-b421e41b3d2f
# 2  1cd08ffd-4e85-4f1d-bdc1-afb292b056db
# 3  d518ff19-df6a-445f-a13c-8b45b2addd7b
# 4  c2baa4bc-9fe3-4cfe-809f-c52a728fa5bb

# %%
# verificando missing values
df_orders.isna().sum()
# Out:
# id         0
# created    0
# value      0
# form_id    0
# dtype: int64

# %%
df_orders['value'].sum()
# Out:
# 374391.95999999996

# %%
#fazendo join das bases
query_final = "SELECT f.id, hair_type, age, created, value FROM forms f LEFT JOIN orders o ON f.id = o.form_id"
df_query_final = pd.read_sql (query_final, con=engine)

# %%
df_query_final.shape
# Out:
# (5000, 5)

# %%
df_query_final['value'].sum()
# Out:
# 374391.95999999996
